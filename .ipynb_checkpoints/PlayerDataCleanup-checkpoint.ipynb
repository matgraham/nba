# %%
import pandas as pd
import numpy as np
import itertools
import csv

# %%
#Dump the stats dataframe into a csv and clean it up
cols = ['Name', 'Team', 'Position','Height', 'Weight']
statsDF = pd.read_csv('players.csv', header= None, names=cols, index_col=False, error_bad_lines=False, delim_whitespace=True)
statsDF[cols] = statsDF[cols].replace({'\$': '', ',': ''}, regex=True)

# %%
#index 0
first_name = []
#index 1
last_name = []
#index 2
position = []
#index 3
height = []
#index 5
team =[]
for index, row in statsDF.iterrows():
    if index % 6 == 0:
        first_name.append(statsDF.iloc[index-6][0])
        last_name.append(statsDF.iloc[index-5][0])
        position.append(statsDF.iloc[index-4][0])
        height.append(statsDF.iloc[index-3][0])
        team.append(statsDF.iloc[index-1][0])

# %%
players_dict = {'First Name':first_name,"Last Name":last_name,'Position':position,'Height':height,'Team':team}

# %%
playersDf = pd.DataFrame(players_dict)

# %%
playersDf
# Out:
#     First Name Height      Last Name        Position  \
# 0        Ivica      7          Zubac          Center
# 1         Alex      6        Abrines           Guard
# 2       Quincy      6            Acy         Forward
# 3       Steven      7          Adams          Center
# 4          Bam      6        Adebayo  Center-Forward
# 5        Arron      6        Afflalo           Guard
# 6       Alexis      7         Ajinca          Center
# 7         Cole      6        Aldrich          Center
# 8     LaMarcus      6       Aldridge         Forward
# 9      Jarrett      6          Allen          Center
# 10      Kadeem      6          Allen           Guard
# 11   Al-Farouq      6          Aminu         Forward
# 12      Justin      6       Anderson   Guard-Forward
# 13        Kyle      6       Anderson         Forward
# 14        Ryan      6       Anderson         Forward
# 15         Ike      6       Anigbogu          Center
# 16     Giannis      6  Antetokounmpo         Forward
# 17     Carmelo      6        Anthony         Forward
# 18          OG      6        Anunoby         Forward
# 19        Ryan      6    Arcidiacono           Guard
# 20      Trevor      6          Ariza   Forward-Guard
# 21     Darrell      6         Arthur         Forward
# 22       Jamel      6          Artis           Guard
# 23        Omer      7           Asik          Center
# 24        D.J.      6       Augustin           Guard
# 25        Luke      6        Babbitt         Forward
# 26      Dwayne      6          Bacon         Forward
# 27         Ron      6          Baker           Guard
# 28        Wade      6        Baldwin           Guard
# 29       Lonzo      6           Ball           Guard
# ..         ...    ...            ...             ...
# 475    Derrick      6         Walton           Guard
# 476         TJ      6         Warren         Forward
# 477     Travis      6           Wear         Forward
# 478      James      6           Webb         Forward
# 479    Briante      6          Weber           Guard
# 480    Russell      6      Westbrook           Guard
# 481      David      6           West         Forward
# 482     Andrew      6          White         Forward
# 483    Derrick      6          White           Guard
# 484     Isaiah      6      Whitehead           Guard
# 485      Okaro      6          White         Forward
# 486     Hassan      7      Whiteside          Center
# 487     Andrew      6        Wiggins         Forward
# 488         CJ      6         Wilcox           Guard
# 489       Alan      6       Williams  Forward-Center
# 490       C.J.      6       Williams   Forward-Guard
# 491        Lou      6       Williams           Guard
# 492     Marvin      6       Williams         Forward
# 493       Troy      6       Williams         Forward
# 494       D.J.      6         Wilson         Forward
# 495    Justise      6        Winslow         Forward
# 496      Delon      6         Wright           Guard
# 497  Guerschon      6       Yabusele         Forward
# 498        Joe      6          Young           Guard
# 499       Nick      6          Young   Guard-Forward
# 500   Thaddeus      6          Young         Forward
# 501       Cody      7         Zeller  Center-Forward
# 502      Tyler      7         Zeller          Center
# 503       Paul      6         Zipser         Forward
# 504       Ante      6          Zizic  Forward-Center
#
#                                        Team
# 0          http://www.nba.com/teams/lakers/
# 1         http://www.nba.com/teams/thunder/
# 2            http://www.nba.com/teams/nets/
# 3         http://www.nba.com/teams/thunder/
# 4            http://www.nba.com/teams/heat/
# 5           http://www.nba.com/teams/magic/
# 6        http://www.nba.com/teams/pelicans/
# 7    http://www.nba.com/teams/timberwolves/
# 8           http://www.nba.com/teams/spurs/
# 9            http://www.nba.com/teams/nets/
# 10        http://www.nba.com/teams/celtics/
# 11        http://www.nba.com/teams/blazers/
# 12         http://www.nba.com/teams/sixers/
# 13          http://www.nba.com/teams/spurs/
# 14        http://www.nba.com/teams/rockets/
# 15         http://www.nba.com/teams/pacers/
# 16          http://www.nba.com/teams/bucks/
# 17        http://www.nba.com/teams/thunder/
# 18        http://www.nba.com/teams/raptors/
# 19          http://www.nba.com/teams/bulls/
# 20        http://www.nba.com/teams/rockets/
# 21        http://www.nba.com/teams/nuggets/
# 22          http://www.nba.com/teams/magic/
# 23          http://www.nba.com/teams/bulls/
# 24          http://www.nba.com/teams/magic/
# 25           http://www.nba.com/teams/heat/
# 26        http://www.nba.com/teams/hornets/
# 27         http://www.nba.com/teams/knicks/
# 28        http://www.nba.com/teams/blazers/
# 29         http://www.nba.com/teams/lakers/
# ..                                      ...
# 475          http://www.nba.com/teams/heat/
# 476          http://www.nba.com/teams/suns/
# 477        http://www.nba.com/teams/lakers/
# 478          http://www.nba.com/teams/nets/
# 479     http://www.nba.com/teams/grizzlies/
# 480       http://www.nba.com/teams/thunder/
# 481      http://www.nba.com/teams/warriors/
# 482         http://www.nba.com/teams/hawks/
# 483         http://www.nba.com/teams/spurs/
# 484          http://www.nba.com/teams/nets/
# 485     http://www.nba.com/teams/cavaliers/
# 486          http://www.nba.com/teams/heat/
# 487  http://www.nba.com/teams/timberwolves/
# 488       http://www.nba.com/teams/blazers/
# 489          http://www.nba.com/teams/suns/
# 490      http://www.nba.com/teams/clippers/
# 491      http://www.nba.com/teams/clippers/
# 492       http://www.nba.com/teams/hornets/
# 493        http://www.nba.com/teams/knicks/
# 494         http://www.nba.com/teams/bucks/
# 495          http://www.nba.com/teams/heat/
# 496       http://www.nba.com/teams/raptors/
# 497       http://www.nba.com/teams/celtics/
# 498        http://www.nba.com/teams/pacers/
# 499      http://www.nba.com/teams/warriors/
# 500        http://www.nba.com/teams/pacers/
# 501       http://www.nba.com/teams/hornets/
# 502         http://www.nba.com/teams/bucks/
# 503         http://www.nba.com/teams/bulls/
# 504     http://www.nba.com/teams/cavaliers/
#
# [505 rows x 5 columns]

# %%
def team_cleanup(string):
    return string[25:-1]

# %%
playersDf['Team'] = playersDf['Team'].apply(team_cleanup)

# %%
playersDf.head()
# Out:
#   First Name Height Last Name        Position     Team
# 0      Ivica      7     Zubac          Center   lakers
# 1       Alex      6   Abrines           Guard  thunder
# 2     Quincy      6       Acy         Forward     nets
# 3     Steven      7     Adams          Center  thunder
# 4        Bam      6   Adebayo  Center-Forward     heat

# %%
playersDf.to_csv('player_database.csv', index=False)
